# %%
import diplib

import cv2
from matplotlib import pyplot as plt

# %%
filepath = 'homework2/hand1.mov'
frames = diplib.get_video_frames(filepath)

# %%
plt.imshow(cv2.cvtColor(frames[50], cv2.COLOR_BGR2RGB))
plt.show()
