# %% [markdown]
# # Connected component
#
# - Event queue: queue that saves events to trigger in order. It can be a stack(=DFS), queue(=BFS) or other
# - Traversing components, any type of event queue can check connected copmponents
